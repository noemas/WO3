# %%
import numpy as np
import matplotlib.pyplot as plt

volume_32 = 7.3236460686 * 7.7495899200 * 7.3236460686
ry_to_mev = 13.605698066 * 1000


a0 = np.loadtxt("DATA/ENERGIES/energies_P2Q_P421c_unstrained.txt")
a1 = np.loadtxt("DATA/ENERGIES/energies_P2Q_P421c_unstrained_doped_e_0.2.txt")
a2 = np.loadtxt("DATA/ENERGIES/energies_P2Q_P421c_unstrained_doped_e_0.6.txt")

b0 = np.loadtxt("DATA/ENERGIES/energies_P2Q_P421c_2_unstrained.txt")
b1 = np.loadtxt("DATA/ENERGIES/energies_P2Q_P421c_2_unstrained_doped_e_0.2.txt")
b2 = np.loadtxt("DATA/ENERGIES/energies_P2Q_P421c_2_unstrained_doped_e_0.6.txt")

plt.figure(0)
plt.plot(a0[:,0], (a0[:,1]-a0[0,1])*ry_to_mev/volume_32, color="blue")
plt.plot(b0[:,0], (b0[:,1]-b0[0,1])*ry_to_mev/volume_32, color="red")
plt.ylim([-0.1,0.5])

plt.figure(1)
plt.plot(a1[:,0], (a1[:,1]-a1[0,1])*ry_to_mev/volume_32, color="blue")
plt.plot(b1[:,0], (b1[:,1]-b1[0,1])*ry_to_mev/volume_32, color="red")
plt.ylim([-0.1,0.5])

plt.figure(2)
plt.plot(a2[:,0], (a2[:,1]-a2[0,1])*ry_to_mev/volume_32, color="blue")
plt.plot(b2[:,0], (b2[:,1]-b2[0,1])*ry_to_mev/volume_32, color="red")
plt.ylim([-0.1,0.5])

plt.show()
