# %%
import numpy
import matplotlib.pyplot as plt

test = numpy.loadtxt("DATA/DOMAIN_WALLS/test.Neel_varQ")
n201_e0 = numpy.loadtxt("DATA/DOMAIN_WALLS/n201_e0.Neel_varQ_charge")

plt.figure(1)
plt.plot(test[:,0], test[:,1])
plt.plot(n201_e0[:,0], n201_e0[:,1])

plt.figure(2)
plt.plot(test[:,0], test[:,2])
plt.plot(n201_e0[:,0], n201_e0[:,2])

def phi_arctan(x, xi):
    return numpy.arctan(numpy.exp(x/xi))

def q_gauss(x, a, b, c):
    return a + b*numpy.exp(-c*(x)**2)

def q_tanh(x, xi):
    return abs(numpy.tanh(x/xi))

popt_Ginzburg, pcov_Ginzburg = sc.optimize.curve_fit(Ginzburg_poly, x[0:M_x_max] , w2fh_vec[0:M_x_max], p0)
