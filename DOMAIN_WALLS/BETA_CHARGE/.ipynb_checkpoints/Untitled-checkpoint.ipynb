# %%
import matplotlib.pyplot as plt
import numpy

charge_diff = numpy.loadtxt('CHG_DIFF.txt')

cell_length = 83.737472
cell_volume = cell_length * 10.468720 * 7.649663
x = numpy.linspace(0,  cell_length, len(charge_diff))
plt.figure(1, figsize=[10,10])

plt.plot(x, charge_diff[:,1])
plt.xlabel("$x [\mathring{A}]$")
plt.ylabel("$planar charge []")
# Out:
# Text(0.5, 0, '$x [\\mathring{A}]$')
